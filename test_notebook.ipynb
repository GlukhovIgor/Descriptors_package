# %%
import pandas as pd
pd.set_option('max_columns', 500)

# %%
import biodescriptors

# %%
filedir = 'test_data/input_data/TX-PGC1-L3-100pdb/'
output_filename = 'test_data/output_data/1st_test.csv'

# %%
clamp_resid = [246, 264, 420]
href = [[127,142], [149,152], [226,246], [257,265], [268, 278], [298,302], [308,322], [328,338], [350,369], [379,396], [397,406], [411,413], [417,423]]

# %%
df_com_protein = biodescriptors.calculating.calc_COM_protein('test_data/input_data/TX-PGC1-L3-100pdb/TX-PGC1-L3-auto_0.pdb')

# %%
df_com_protein
# Out:
# [0.04539215875281678, 0.08702205649887824, -0.15437526106351596]

# %%
df_final = biodescriptors.calculating.calc_all(filedir, output_filename, clamp_resid, href)
# Out:
# calculating 1 out of 101, structure - TX-PGC1-L3-auto_0.pdb
# KeyError while calculating alpha angle
# calculating 2 out of 101, structure - TX-PGC1-L3-auto_1.pdb
# KeyError while calculating alpha angle
# calculating 3 out of 101, structure - TX-PGC1-L3-auto_10.pdb
# KeyError while calculating alpha angle
# calculating 4 out of 101, structure - TX-PGC1-L3-auto_100.pdb
# KeyError while calculating alpha angle
# calculating 5 out of 101, structure - TX-PGC1-L3-auto_11.pdb
# KeyError while calculating alpha angle
# calculating 6 out of 101, structure - TX-PGC1-L3-auto_12.pdb
# KeyError while calculating alpha angle
# calculating 7 out of 101, structure - TX-PGC1-L3-auto_13.pdb
# KeyError while calculating alpha angle
# calculating 8 out of 101, structure - TX-PGC1-L3-auto_14.pdb
# KeyError while calculating alpha angle
# calculating 9 out of 101, structure - TX-PGC1-L3-auto_15.pdb
# KeyError while calculating alpha angle
# calculating 10 out of 101, structure - TX-PGC1-L3-auto_16.pdb
# KeyError while calculating alpha angle
# calculating 11 out of 101, structure - TX-PGC1-L3-auto_17.pdb
# KeyError while calculating alpha angle
# calculating 12 out of 101, structure - TX-PGC1-L3-auto_18.pdb
# KeyError while calculating alpha angle
# calculating 13 out of 101, structure - TX-PGC1-L3-auto_19.pdb
# KeyError while calculating alpha angle
# calculating 14 out of 101, structure - TX-PGC1-L3-auto_2.pdb
# KeyError while calculating alpha angle
# calculating 15 out of 101, structure - TX-PGC1-L3-auto_20.pdb
# KeyError while calculating alpha angle
# calculating 16 out of 101, structure - TX-PGC1-L3-auto_21.pdb
# KeyError while calculating alpha angle
# calculating 17 out of 101, structure - TX-PGC1-L3-auto_22.pdb
# KeyError while calculating alpha angle
# calculating 18 out of 101, structure - TX-PGC1-L3-auto_23.pdb
# KeyError while calculating alpha angle
# calculating 19 out of 101, structure - TX-PGC1-L3-auto_24.pdb
# KeyError while calculating alpha angle
# calculating 20 out of 101, structure - TX-PGC1-L3-auto_25.pdb
# KeyError while calculating alpha angle
# calculating 21 out of 101, structure - TX-PGC1-L3-auto_26.pdb
# KeyError while calculating alpha angle
# calculating 22 out of 101, structure - TX-PGC1-L3-auto_27.pdb
# KeyError while calculating alpha angle
# calculating 23 out of 101, structure - TX-PGC1-L3-auto_28.pdb
# KeyError while calculating alpha angle
# calculating 24 out of 101, structure - TX-PGC1-L3-auto_29.pdb
# KeyError while calculating alpha angle
# calculating 25 out of 101, structure - TX-PGC1-L3-auto_3.pdb
# KeyError while calculating alpha angle
# calculating 26 out of 101, structure - TX-PGC1-L3-auto_30.pdb
# KeyError while calculating alpha angle
# calculating 27 out of 101, structure - TX-PGC1-L3-auto_31.pdb
# KeyError while calculating alpha angle
# calculating 28 out of 101, structure - TX-PGC1-L3-auto_32.pdb
# KeyError while calculating alpha angle
# calculating 29 out of 101, structure - TX-PGC1-L3-auto_33.pdb
# KeyError while calculating alpha angle
# calculating 30 out of 101, structure - TX-PGC1-L3-auto_34.pdb
# KeyError while calculating alpha angle
# calculating 31 out of 101, structure - TX-PGC1-L3-auto_35.pdb
# KeyError while calculating alpha angle
# calculating 32 out of 101, structure - TX-PGC1-L3-auto_36.pdb
# KeyError while calculating alpha angle
# calculating 33 out of 101, structure - TX-PGC1-L3-auto_37.pdb
# KeyError while calculating alpha angle
# calculating 34 out of 101, structure - TX-PGC1-L3-auto_38.pdb
# KeyError while calculating alpha angle
# calculating 35 out of 101, structure - TX-PGC1-L3-auto_39.pdb
# KeyError while calculating alpha angle
# calculating 36 out of 101, structure - TX-PGC1-L3-auto_4.pdb
# KeyError while calculating alpha angle
# calculating 37 out of 101, structure - TX-PGC1-L3-auto_40.pdb
# KeyError while calculating alpha angle
# calculating 38 out of 101, structure - TX-PGC1-L3-auto_41.pdb
# KeyError while calculating alpha angle
# calculating 39 out of 101, structure - TX-PGC1-L3-auto_42.pdb
# KeyError while calculating alpha angle
# calculating 40 out of 101, structure - TX-PGC1-L3-auto_43.pdb
# KeyError while calculating alpha angle
# calculating 41 out of 101, structure - TX-PGC1-L3-auto_44.pdb
# KeyError while calculating alpha angle
# calculating 42 out of 101, structure - TX-PGC1-L3-auto_45.pdb
# KeyError while calculating alpha angle
# calculating 43 out of 101, structure - TX-PGC1-L3-auto_46.pdb
# KeyError while calculating alpha angle
# calculating 44 out of 101, structure - TX-PGC1-L3-auto_47.pdb
# KeyError while calculating alpha angle
# calculating 45 out of 101, structure - TX-PGC1-L3-auto_48.pdb
# KeyError while calculating alpha angle
# calculating 46 out of 101, structure - TX-PGC1-L3-auto_49.pdb
# KeyError while calculating alpha angle
# calculating 47 out of 101, structure - TX-PGC1-L3-auto_5.pdb
# KeyError while calculating alpha angle
# calculating 48 out of 101, structure - TX-PGC1-L3-auto_50.pdb
# KeyError while calculating alpha angle
# calculating 49 out of 101, structure - TX-PGC1-L3-auto_51.pdb
# KeyError while calculating alpha angle
# calculating 50 out of 101, structure - TX-PGC1-L3-auto_52.pdb
# KeyError while calculating alpha angle
# calculating 51 out of 101, structure - TX-PGC1-L3-auto_53.pdb
# KeyError while calculating alpha angle
# calculating 52 out of 101, structure - TX-PGC1-L3-auto_54.pdb
# KeyError while calculating alpha angle
# calculating 53 out of 101, structure - TX-PGC1-L3-auto_55.pdb
# KeyError while calculating alpha angle
# calculating 54 out of 101, structure - TX-PGC1-L3-auto_56.pdb
# KeyError while calculating alpha angle
# calculating 55 out of 101, structure - TX-PGC1-L3-auto_57.pdb
# KeyError while calculating alpha angle
# calculating 56 out of 101, structure - TX-PGC1-L3-auto_58.pdb
# KeyError while calculating alpha angle
# calculating 57 out of 101, structure - TX-PGC1-L3-auto_59.pdb
# KeyError while calculating alpha angle
# calculating 58 out of 101, structure - TX-PGC1-L3-auto_6.pdb
# KeyError while calculating alpha angle
# calculating 59 out of 101, structure - TX-PGC1-L3-auto_60.pdb
# KeyError while calculating alpha angle
# calculating 60 out of 101, structure - TX-PGC1-L3-auto_61.pdb
# KeyError while calculating alpha angle
# calculating 61 out of 101, structure - TX-PGC1-L3-auto_62.pdb
# KeyError while calculating alpha angle
# calculating 62 out of 101, structure - TX-PGC1-L3-auto_63.pdb
# KeyError while calculating alpha angle
# calculating 63 out of 101, structure - TX-PGC1-L3-auto_64.pdb
# KeyError while calculating alpha angle
# calculating 64 out of 101, structure - TX-PGC1-L3-auto_65.pdb
# KeyError while calculating alpha angle
# calculating 65 out of 101, structure - TX-PGC1-L3-auto_66.pdb
# KeyError while calculating alpha angle
# calculating 66 out of 101, structure - TX-PGC1-L3-auto_67.pdb
# KeyError while calculating alpha angle
# calculating 67 out of 101, structure - TX-PGC1-L3-auto_68.pdb
# KeyError while calculating alpha angle
# calculating 68 out of 101, structure - TX-PGC1-L3-auto_69.pdb
# KeyError while calculating alpha angle
# calculating 69 out of 101, structure - TX-PGC1-L3-auto_7.pdb
# KeyError while calculating alpha angle
# calculating 70 out of 101, structure - TX-PGC1-L3-auto_70.pdb
# KeyError while calculating alpha angle
# calculating 71 out of 101, structure - TX-PGC1-L3-auto_71.pdb
# KeyError while calculating alpha angle
# calculating 72 out of 101, structure - TX-PGC1-L3-auto_72.pdb
# KeyError while calculating alpha angle
# calculating 73 out of 101, structure - TX-PGC1-L3-auto_73.pdb
# KeyError while calculating alpha angle
# calculating 74 out of 101, structure - TX-PGC1-L3-auto_74.pdb
# KeyError while calculating alpha angle
# calculating 75 out of 101, structure - TX-PGC1-L3-auto_75.pdb
# KeyError while calculating alpha angle
# calculating 76 out of 101, structure - TX-PGC1-L3-auto_76.pdb
# KeyError while calculating alpha angle
# calculating 77 out of 101, structure - TX-PGC1-L3-auto_77.pdb
# KeyError while calculating alpha angle
# calculating 78 out of 101, structure - TX-PGC1-L3-auto_78.pdb
# KeyError while calculating alpha angle
# calculating 79 out of 101, structure - TX-PGC1-L3-auto_79.pdb
# KeyError while calculating alpha angle
# calculating 80 out of 101, structure - TX-PGC1-L3-auto_8.pdb
# KeyError while calculating alpha angle
# calculating 81 out of 101, structure - TX-PGC1-L3-auto_80.pdb
# KeyError while calculating alpha angle
# calculating 82 out of 101, structure - TX-PGC1-L3-auto_81.pdb
# KeyError while calculating alpha angle
# calculating 83 out of 101, structure - TX-PGC1-L3-auto_82.pdb
# KeyError while calculating alpha angle
# calculating 84 out of 101, structure - TX-PGC1-L3-auto_83.pdb
# KeyError while calculating alpha angle
# calculating 85 out of 101, structure - TX-PGC1-L3-auto_84.pdb
# KeyError while calculating alpha angle
# calculating 86 out of 101, structure - TX-PGC1-L3-auto_85.pdb
# KeyError while calculating alpha angle
# calculating 87 out of 101, structure - TX-PGC1-L3-auto_86.pdb
# KeyError while calculating alpha angle
# calculating 88 out of 101, structure - TX-PGC1-L3-auto_87.pdb
# KeyError while calculating alpha angle
# calculating 89 out of 101, structure - TX-PGC1-L3-auto_88.pdb
# KeyError while calculating alpha angle
# calculating 90 out of 101, structure - TX-PGC1-L3-auto_89.pdb
# KeyError while calculating alpha angle
# calculating 91 out of 101, structure - TX-PGC1-L3-auto_9.pdb
# KeyError while calculating alpha angle
# calculating 92 out of 101, structure - TX-PGC1-L3-auto_90.pdb
# KeyError while calculating alpha angle
# calculating 93 out of 101, structure - TX-PGC1-L3-auto_91.pdb
# KeyError while calculating alpha angle
# calculating 94 out of 101, structure - TX-PGC1-L3-auto_92.pdb
# KeyError while calculating alpha angle
# calculating 95 out of 101, structure - TX-PGC1-L3-auto_93.pdb
# KeyError while calculating alpha angle
# calculating 96 out of 101, structure - TX-PGC1-L3-auto_94.pdb
# KeyError while calculating alpha angle
# calculating 97 out of 101, structure - TX-PGC1-L3-auto_95.pdb
# KeyError while calculating alpha angle
# calculating 98 out of 101, structure - TX-PGC1-L3-auto_96.pdb
# KeyError while calculating alpha angle
# calculating 99 out of 101, structure - TX-PGC1-L3-auto_97.pdb
# KeyError while calculating alpha angle
# calculating 100 out of 101, structure - TX-PGC1-L3-auto_98.pdb
# KeyError while calculating alpha angle
# calculating 101 out of 101, structure - TX-PGC1-L3-auto_99.pdb
# KeyError while calculating alpha angle
